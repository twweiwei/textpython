# %%
a=7
print(a)
# Out:
# 7

# %%
b=a
print(b)
# Out:
# 7

# %%
type(a)
# Out:
# int

# %%
type(58)
# Out:
# int

# %%
type(99.3)
# Out:
# float

# %%
type("abc")
# Out:
# str

# %%
5
# Out:
# 5

# %%
0
# Out:
# 0

# %%
05
# Out:
#   File "<ipython-input-10-b139c77ba8b1>", line 1
#     05
#      ^
# SyntaxError: invalid token

# %%
+123
# Out:
# 123

# %%
5+9
# Out:
# 14

# %%
100-7
# Out:
# 93

# %%
4-10
# Out:
# -6

# %%
5+9+      3
# Out:
# 17

# %%
6*7
# Out:
# 42

# %%
9/5
# Out:
# 1.8

# %%
9//85
# Out:
# 0

# %%
9//5
# Out:
# 1

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-20-67a69f72677d> in <module>()
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
a=95
a
# Out:
# 95

# %%
a-=3

# %%
a-=3
a
# Out:
# 89

# %%
a+=8
a
# Out:
# 97

# %%
a*=2
a
# Out:
# 194

# %%
2+3*4
# Out:
# 14

# %%
int(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-46d5263ce506> in <module>()
# ----> 1 int(true)
#
# NameError: name 'true' is not defined

# %%
inr(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-dfec64f8e375> in <module>()
# ----> 1 inr(True)
#
# NameError: name 'inr' is not defined

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(False)
# Out:
# 0

# %%
int(98.6)
# Out:
# 98

# %%
int("99")
# Out:
# 99

# %%
int('-23')
# Out:
# -23

# %%
int('+12')
# Out:
# 12

# %%
120b
# Out:
#   File "<ipython-input-39-ff6797de9184>", line 1
#     120b
#        ^
# SyntaxError: invalid syntax

# %%
0b12
# Out:
#   File "<ipython-input-40-25e53e8d1f34>", line 1
#     0b12
#        ^
# SyntaxError: invalid syntax

# %%
0b10
# Out:
# 2

# %%
divmod(9,5)
# Out:
# (1, 4)
